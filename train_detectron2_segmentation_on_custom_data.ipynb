# %% [markdown]
# ## Introduction

# %% [markdown]
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">
#
# **How to Train [Detectron2](https://github.com/facebookresearch/detectron2) Segmentation on a Custom Dataset**
#
# The notebook is based on official Detectron2 [colab notebook](https://colab.research.google.com/drive/16jcaJoc6bCFAQ96jDe2HwtXj7BMD_-m5) and it covers:
# - Python environment setup
# - Inference using pre-trained models
# - Download, register and visualize COCO Format Dataset
# - Configure, train and evaluate model using custom COCO Format Dataset
#
# **Preparing a Custom Dataset**
#
# In this tutorial, we will utilize an open source computer vision dataset from one of the 100,000+ available on [Roboflow Universe](https://universe.roboflow.com).
#
# If you already have your own images (and, optionally, annotations), you can convert your dataset using [Roboflow](https://roboflow.com), a set of tools developers use to build better computer vision models quickly and accurately. 150k+ developers use roboflow for (automatic) annotation, converting dataset formats (like to Detectron2), training, deploying, and improving their datasets/models.
#
# Follow [the getting started guide here](https://docs.roboflow.com/quick-start) to create and prepare your own custom dataset. Make sure to select **Instance Segmentation** Option, If you want to create your own dataset on roboflow
#
# Useful Dataset Links
#
# * [Helmet Instace Segmentation ](https://universe.roboflow.com/computer-vision-hx9i9/helmet_polygon_v2/dataset/4)
#
# * [PCB Board Instance Segmentation](https://universe.roboflow.com/chip/pcb_segmentation_yolov7/dataset/17)
#
# * [Fire Segmentation Instance Segmentation](https://universe.roboflow.com/fire-instance-segmentation/fire-detection-pr6nj/dataset/1)

# %% [markdown]
# ## Before you start

# %% [markdown]
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator` and set it to `GPU`.

# %%
# !nvidia-smi
# Out:
# Wed Jan 10 07:39:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0              28W /  70W |   1649MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Install Detectron2 and dependencies

# %%
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-dmyp28og
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-dmyp28og
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 864913f0e57e87a75c8cc0c7d79ecbd774fc669b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.4.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.15.1)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (3.2.2)

# %% [markdown]
# Now is a good time to confirm that we have the right versions of the libraries at our disposal.

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# torch:  2.1 ; cuda:  cu121
# detectron2: 0.6

# %%
# COMMON LIBRARIES
import os
import cv2

from datetime import datetime
from google.colab.patches import cv2_imshow

# DATA SET PREPARATION AND LOADING
from detectron2.data.datasets import register_coco_instances
from detectron2.data import DatasetCatalog, MetadataCatalog

# VISUALIZATION
from detectron2.utils.visualizer import Visualizer
from detectron2.utils.visualizer import ColorMode

# CONFIGURATION
from detectron2 import model_zoo
from detectron2.config import get_cfg

# EVALUATION
from detectron2.engine import DefaultPredictor

# TRAINING
from detectron2.engine import DefaultTrainer

# %% [markdown]
# ## Run a Pre-trained Detectron2 Model

# %% [markdown]
# Before you start training, it's a good idea to check that everything is working properly. The best way to do this is to perform inference using a pre-trained model.

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg
image = cv2.imread("/content/object/object.jpg,/content/object/computer.jpg ")
cv2_imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-59bce32688bb> in <cell line: 3>()
#       1 get_ipython().system('wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg')
#       2 image = cv2.imread("/content/object/object.jpg ,/content/object/computer.jpg ")
# ----> 3 cv2_imshow(image)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
outputs = predictor(image)
# Out:
# model_final_f10217.pkl: 178MB [00:09, 17.9MB/s]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
print(outputs["instances"].pred_classes)
print(outputs["instances"].pred_boxes)
# Out:
# tensor([17,  0,  0,  0,  0,  0,  0,  0, 25,  0, 25, 25,  0,  0, 24],
#        device='cuda:0')
# Boxes(tensor([[126.6035, 244.8977, 459.8291, 480.0000],
#         [251.1083, 157.8127, 338.9731, 413.6379],
#         [114.8496, 268.6864, 148.2352, 398.8111],
#         [  0.8217, 281.0327,  78.6072, 478.4210],
#         [ 49.3953, 274.1229,  80.1545, 342.9808],
#         [561.2248, 271.5816, 596.2755, 385.2552],
#         [385.9072, 270.3125, 413.7130, 304.0397],
#         [515.9295, 278.3744, 562.2792, 389.3802],
#         [335.2409, 251.9167, 414.7491, 275.9375],
#         [350.9300, 269.2060, 386.0984, 297.9081],
#         [331.6292, 230.9996, 393.2759, 257.2009],
#         [510.7349, 263.2656, 570.9865, 295.9194],
#         [409.0841, 271.8646, 460.5582, 356.8722],
#         [506.8767, 283.3257, 529.9403, 324.0392],
#         [594.5663, 283.4820, 609.0577, 311.4124]], device='cuda:0'))

# %%
visualizer = Visualizer(image[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = visualizer.draw_instance_predictions(outputs["instances"].to("cpu"))
cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F702C04B3D0>

# %% [markdown]
# ## COCO Format Dataset

# %% [markdown]
# ### Download

# %% [markdown]
# We use `football-pitch-segmentation` dataset as example. Feel free to visit [Roboflow Universe](https://universe.roboflow.com/), and select any other Instance Segmentation dataset. Make sure to download the dataset in correct - `COCO Segmentation` format.
#
# Structure of your dataset should look like this:
#
# ```
# dataset-directory/
# ├─ README.dataset.txt
# ├─ README.roboflow.txt
# ├─ train
# │  ├─ train-image-1.jpg
# │  ├─ train-image-1.jpg
# │  ├─ ...
# │  └─ _annotations.coco.json
# ├─ test
# │  ├─ test-image-1.jpg
# │  ├─ test-image-1.jpg
# │  ├─ ...
# │  └─ _annotations.coco.json
# └─ valid
#    ├─ valid-image-1.jpg
#    ├─ valid-image-1.jpg
#    ├─ ...
#    └─ _annotations.coco.json
# ```

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QL7VElr3am2bTh7OR53z")
project = rf.workspace("roboflow-jvuqo").project("football-pitch-segmentation")
dataset = project.version(1).download("coco-segmentation")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: roboflow in /usr/local/lib/python3.7/dist-packages (0.2.18)
# Requirement already satisfied: opencv-python-headless>=4.5.1.48 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.6.0.66)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: certifi==2021.5.30 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2021.5.30)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.1)
# Requirement already satisfied: urllib3==1.26.6 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.26.6)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.28.1)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.7)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (7.1.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.64.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.21.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.3.1->roboflow) (4.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->roboflow) (2.1.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-pitch-segmentation-1 to coco-segmentation: 100% [23935991 / 23935991] bytes
# Extracting Dataset Version Zip to football-pitch-segmentation-1 in coco-segmentation:: 100%|██████████| 368/368 [00:00<00:00, 1089.15it/s]

# %% [markdown]
# ### Register

# %% [markdown]
# When you use Detectron2, before you actually train the model you need to [register it](https://detectron2.readthedocs.io/en/latest/tutorials/datasets.html#register-a-coco-format-dataset).

# %%
DATA_SET_NAME = dataset.name.replace(" ", "-")
ANNOTATIONS_FILE_NAME = "_annotations.coco.json"

# %%
# TRAIN SET
TRAIN_DATA_SET_NAME = f"{DATA_SET_NAME}-train"
TRAIN_DATA_SET_IMAGES_DIR_PATH = os.path.join(dataset.location, "train")
TRAIN_DATA_SET_ANN_FILE_PATH = os.path.join(dataset.location, "train", ANNOTATIONS_FILE_NAME)

register_coco_instances(
    name=TRAIN_DATA_SET_NAME,
    metadata={},
    json_file=TRAIN_DATA_SET_ANN_FILE_PATH,
    image_root=TRAIN_DATA_SET_IMAGES_DIR_PATH
)

# TEST SET
TEST_DATA_SET_NAME = f"{DATA_SET_NAME}-test"
TEST_DATA_SET_IMAGES_DIR_PATH = os.path.join(dataset.location, "test")
TEST_DATA_SET_ANN_FILE_PATH = os.path.join(dataset.location, "test", ANNOTATIONS_FILE_NAME)

register_coco_instances(
    name=TEST_DATA_SET_NAME,
    metadata={},
    json_file=TEST_DATA_SET_ANN_FILE_PATH,
    image_root=TEST_DATA_SET_IMAGES_DIR_PATH
)

# VALID SET
VALID_DATA_SET_NAME = f"{DATA_SET_NAME}-valid"
VALID_DATA_SET_IMAGES_DIR_PATH = os.path.join(dataset.location, "valid")
VALID_DATA_SET_ANN_FILE_PATH = os.path.join(dataset.location, "valid", ANNOTATIONS_FILE_NAME)

register_coco_instances(
    name=VALID_DATA_SET_NAME,
    metadata={},
    json_file=VALID_DATA_SET_ANN_FILE_PATH,
    image_root=VALID_DATA_SET_IMAGES_DIR_PATH
)

# %% [markdown]
# We can now confirm that our custom dataset was correctly registered using [MetadataCatalog](https://detectron2.readthedocs.io/en/latest/modules/data.html#detectron2.data.MetadataCatalog).

# %%
[
    data_set
    for data_set
    in MetadataCatalog.list()
    if data_set.startswith(DATA_SET_NAME)
]
# Out:
# ['football-pitch-segmentation-train',
#  'football-pitch-segmentation-test',
#  'football-pitch-segmentation-valid']

# %% [markdown]
# ### Visualize

# %% [markdown]
# Let's take a look at single entry from out train dataset.

# %%
metadata = MetadataCatalog.get(TRAIN_DATA_SET_NAME)
dataset_train = DatasetCatalog.get(TRAIN_DATA_SET_NAME)

dataset_entry = dataset_train[0]
image = cv2.imread(dataset_entry["file_name"])

visualizer = Visualizer(
    image[:, :, ::-1],
    metadata=metadata,
    scale=0.8,
    instance_mode=ColorMode.IMAGE_BW
)

out = visualizer.draw_dataset_dict(dataset_entry)
cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# WARNING:detectron2.data.datasets.coco:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F70281D2F50>

# %% [markdown]
# ## Train Model Using Custom COCO Format Dataset

# %% [markdown]
# ### Configuration

# %%
# HYPERPARAMETERS
ARCHITECTURE = "mask_rcnn_R_101_FPN_3x"
CONFIG_FILE_PATH = f"COCO-InstanceSegmentation/{ARCHITECTURE}.yaml"
MAX_ITER = 2000
EVAL_PERIOD = 200
BASE_LR = 0.001
NUM_CLASSES = 3

# OUTPUT DIR
OUTPUT_DIR_PATH = os.path.join(
    DATA_SET_NAME,
    ARCHITECTURE,
    datetime.now().strftime('%Y-%m-%d-%H-%M-%S')
)

os.makedirs(OUTPUT_DIR_PATH, exist_ok=True)

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file(CONFIG_FILE_PATH))
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(CONFIG_FILE_PATH)
cfg.DATASETS.TRAIN = (TRAIN_DATA_SET_NAME,)
cfg.DATASETS.TEST = (TEST_DATA_SET_NAME,)
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 64
cfg.TEST.EVAL_PERIOD = EVAL_PERIOD
cfg.DATALOADER.NUM_WORKERS = 2
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.INPUT.MASK_FORMAT='bitmask'
cfg.SOLVER.BASE_LR = BASE_LR
cfg.SOLVER.MAX_ITER = MAX_ITER
cfg.MODEL.ROI_HEADS.NUM_CLASSES = NUM_CLASSES
cfg.OUTPUT_DIR = OUTPUT_DIR_PATH

# %% [markdown]
# ### Training

# %%
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [11/09 14:33:41 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# WARNING [11/09 14:33:41 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:33:41 d2.data.datasets.coco]: Loaded 315 images in COCO format from /content/football-pitch-segmentation-1/train/_annotations.coco.json
# [11/09 14:33:41 d2.data.build]: Removed 0 images with no usable annotations. 315 images left.
# [11/09 14:33:41 d2.data.build]: Distribution of instances among all 4 categories:
# |   category    | #instances   |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:-------------:|:-------------|
# | football-pi.. | 0            | cross_recip.. | 372          | crossing_pl.. | 738          |
# |     pitch     | 315          |               |              |               |              |
# |     total     | 1425         |               |              |               |              |
# [11/09 14:33:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [11/09 14:33:41 d2.data.build]: Using training sampler TrainingSampler
# [11/09 14:33:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:33:41 d2.data.common]: Serializing 315 elements to byte tensors and concatenating them all ...
# [11/09 14:33:41 d2.data.common]: Serialized dataset takes 0.26 MiB
# WARNING [11/09 14:33:41 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# model_final_a3ec72.pkl: 254MB [00:13, 19.1MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (12, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (12,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (3, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [11/09 14:33:59 d2.engine.train_loop]: Starting training from iteration 0
# [11/09 14:34:10 d2.utils.events]:  eta: 0:14:15  iter: 19  total_loss: 3.505  loss_cls: 1.285  loss_box_reg: 0.003559  loss_mask: 0.6925  loss_rpn_cls: 1.26  loss_rpn_loc: 0.2499  time: 0.4376  data_time: 0.0220  lr: 1.9981e-05  max_mem: 2756M
# [11/09 14:34:19 d2.utils.events]:  eta: 0:14:16  iter: 39  total_loss: 2.402  loss_cls: 0.9507  loss_box_reg: 0.1008  loss_mask: 0.6898  loss_rpn_cls: 0.4921  loss_rpn_loc: 0.1868  time: 0.4417  data_time: 0.0134  lr: 3.9961e-05  max_mem: 2756M
# [11/09 14:34:28 d2.utils.events]:  eta: 0:14:09  iter: 59  total_loss: 2.168  loss_cls: 0.624  loss_box_reg: 0.3171  loss_mask: 0.6823  loss_rpn_cls: 0.2671  loss_rpn_loc: 0.1999  time: 0.4423  data_time: 0.0100  lr: 5.9941e-05  max_mem: 2756M
# [11/09 14:34:37 d2.utils.events]:  eta: 0:13:59  iter: 79  total_loss: 2.074  loss_cls: 0.5656  loss_box_reg: 0.5143  loss_mask: 0.6796  loss_rpn_cls: 0.177  loss_rpn_loc: 0.1233  time: 0.4393  data_time: 0.0115  lr: 7.9921e-05  max_mem: 2756M
# [11/09 14:34:46 d2.utils.events]:  eta: 0:13:59  iter: 99  total_loss: 2.089  loss_cls: 0.5568  loss_box_reg: 0.5619  loss_mask: 0.6728  loss_rpn_cls: 0.1152  loss_rpn_loc: 0.1269  time: 0.4441  data_time: 0.0142  lr: 9.9901e-05  max_mem: 2756M
# [11/09 14:34:55 d2.utils.events]:  eta: 0:13:49  iter: 119  total_loss: 2.361  loss_cls: 0.5827  loss_box_reg: 0.7308  loss_mask: 0.6613  loss_rpn_cls: 0.1411  loss_rpn_loc: 0.1861  time: 0.4445  data_time: 0.0128  lr: 0.00011988  max_mem: 2756M
# [11/09 14:35:05 d2.utils.events]:  eta: 0:13:48  iter: 139  total_loss: 2.233  loss_cls: 0.5739  loss_box_reg: 0.7381  loss_mask: 0.6527  loss_rpn_cls: 0.07048  loss_rpn_loc: 0.1187  time: 0.4502  data_time: 0.0118  lr: 0.00013986  max_mem: 2756M
# [11/09 14:35:14 d2.utils.events]:  eta: 0:13:42  iter: 159  total_loss: 2.185  loss_cls: 0.5519  loss_box_reg: 0.7816  loss_mask: 0.6409  loss_rpn_cls: 0.06114  loss_rpn_loc: 0.1219  time: 0.4514  data_time: 0.0103  lr: 0.00015984  max_mem: 2756M
# [11/09 14:35:23 d2.utils.events]:  eta: 0:13:36  iter: 179  total_loss: 2.288  loss_cls: 0.5365  loss_box_reg: 0.8711  loss_mask: 0.6154  loss_rpn_cls: 0.08172  loss_rpn_loc: 0.1557  time: 0.4531  data_time: 0.0113  lr: 0.00017982  max_mem: 2756M
# WARNING [11/09 14:35:32 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:35:32 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:35:32 d2.data.build]: Distribution of instances among all 4 categories:
# |   category    | #instances   |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:-------------:|:-------------|
# | football-pi.. | 0            | cross_recip.. | 15           | crossing_pl.. | 32           |
# |     pitch     | 15           |               |              |               |              |
# |     total     | 62           |               |              |               |              |
# [11/09 14:35:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:35:32 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:35:32 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:35:32 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:35:32 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:35:32 d2.utils.events]:  eta: 0:13:28  iter: 199  total_loss: 2.159  loss_cls: 0.5227  loss_box_reg: 0.8742  loss_mask: 0.5862  loss_rpn_cls: 0.0564  loss_rpn_loc: 0.1204  time: 0.4538  data_time: 0.0116  lr: 0.0001998  max_mem: 2756M
# [11/09 14:35:42 d2.utils.events]:  eta: 0:13:22  iter: 219  total_loss: 2.091  loss_cls: 0.4648  loss_box_reg: 0.8544  loss_mask: 0.533  loss_rpn_cls: 0.04622  loss_rpn_loc: 0.148  time: 0.4553  data_time: 0.0091  lr: 0.00021978  max_mem: 2756M
# [11/09 14:35:51 d2.utils.events]:  eta: 0:13:20  iter: 239  total_loss: 2.01  loss_cls: 0.4453  loss_box_reg: 0.8991  loss_mask: 0.4718  loss_rpn_cls: 0.05339  loss_rpn_loc: 0.1234  time: 0.4571  data_time: 0.0117  lr: 0.00023976  max_mem: 2756M
# [11/09 14:36:01 d2.utils.events]:  eta: 0:13:14  iter: 259  total_loss: 1.921  loss_cls: 0.3893  loss_box_reg: 0.9222  loss_mask: 0.4349  loss_rpn_cls: 0.03022  loss_rpn_loc: 0.1041  time: 0.4590  data_time: 0.0133  lr: 0.00025974  max_mem: 2756M
# [11/09 14:36:10 d2.utils.events]:  eta: 0:13:05  iter: 279  total_loss: 1.793  loss_cls: 0.3736  loss_box_reg: 0.8523  loss_mask: 0.3824  loss_rpn_cls: 0.03762  loss_rpn_loc: 0.124  time: 0.4597  data_time: 0.0123  lr: 0.00027972  max_mem: 2756M
# [11/09 14:36:20 d2.utils.events]:  eta: 0:12:56  iter: 299  total_loss: 1.607  loss_cls: 0.3112  loss_box_reg: 0.7936  loss_mask: 0.3515  loss_rpn_cls: 0.03622  loss_rpn_loc: 0.1068  time: 0.4595  data_time: 0.0141  lr: 0.0002997  max_mem: 2756M
# [11/09 14:36:29 d2.utils.events]:  eta: 0:12:47  iter: 319  total_loss: 1.361  loss_cls: 0.2394  loss_box_reg: 0.6968  loss_mask: 0.283  loss_rpn_cls: 0.02568  loss_rpn_loc: 0.1008  time: 0.4599  data_time: 0.0108  lr: 0.00031968  max_mem: 2756M
# [11/09 14:36:39 d2.utils.events]:  eta: 0:12:41  iter: 339  total_loss: 1.28  loss_cls: 0.2289  loss_box_reg: 0.6326  loss_mask: 0.2529  loss_rpn_cls: 0.01855  loss_rpn_loc: 0.09225  time: 0.4612  data_time: 0.0110  lr: 0.00033966  max_mem: 2756M
# [11/09 14:36:48 d2.utils.events]:  eta: 0:12:32  iter: 359  total_loss: 1.21  loss_cls: 0.2365  loss_box_reg: 0.5797  loss_mask: 0.267  loss_rpn_cls: 0.02338  loss_rpn_loc: 0.1175  time: 0.4609  data_time: 0.0104  lr: 0.00035964  max_mem: 2756M
# [11/09 14:36:57 d2.utils.events]:  eta: 0:12:26  iter: 379  total_loss: 1.171  loss_cls: 0.2114  loss_box_reg: 0.6004  loss_mask: 0.2622  loss_rpn_cls: 0.01377  loss_rpn_loc: 0.1049  time: 0.4613  data_time: 0.0117  lr: 0.00037962  max_mem: 2756M
# WARNING [11/09 14:37:06 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:37:06 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:37:06 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:37:06 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:37:06 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:37:06 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:37:06 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:37:06 d2.utils.events]:  eta: 0:12:17  iter: 399  total_loss: 1.186  loss_cls: 0.2077  loss_box_reg: 0.5389  loss_mask: 0.2396  loss_rpn_cls: 0.02147  loss_rpn_loc: 0.1289  time: 0.4615  data_time: 0.0126  lr: 0.0003996  max_mem: 2756M
# [11/09 14:37:16 d2.utils.events]:  eta: 0:12:07  iter: 419  total_loss: 0.9767  loss_cls: 0.1689  loss_box_reg: 0.4578  loss_mask: 0.2062  loss_rpn_cls: 0.01477  loss_rpn_loc: 0.1092  time: 0.4614  data_time: 0.0113  lr: 0.00041958  max_mem: 2756M
# [11/09 14:37:25 d2.utils.events]:  eta: 0:11:58  iter: 439  total_loss: 1.011  loss_cls: 0.17  loss_box_reg: 0.4666  loss_mask: 0.2226  loss_rpn_cls: 0.0148  loss_rpn_loc: 0.08364  time: 0.4620  data_time: 0.0126  lr: 0.00043956  max_mem: 2756M
# [11/09 14:37:35 d2.utils.events]:  eta: 0:11:51  iter: 459  total_loss: 0.9065  loss_cls: 0.1616  loss_box_reg: 0.4291  loss_mask: 0.2038  loss_rpn_cls: 0.01337  loss_rpn_loc: 0.06221  time: 0.4629  data_time: 0.0112  lr: 0.00045954  max_mem: 2756M
# [11/09 14:37:44 d2.utils.events]:  eta: 0:11:44  iter: 479  total_loss: 0.8943  loss_cls: 0.1828  loss_box_reg: 0.4202  loss_mask: 0.2048  loss_rpn_cls: 0.01403  loss_rpn_loc: 0.0807  time: 0.4639  data_time: 0.0116  lr: 0.00047952  max_mem: 2756M
# [11/09 14:37:54 d2.utils.events]:  eta: 0:11:33  iter: 499  total_loss: 0.9281  loss_cls: 0.1776  loss_box_reg: 0.4041  loss_mask: 0.1999  loss_rpn_cls: 0.01844  loss_rpn_loc: 0.09245  time: 0.4635  data_time: 0.0129  lr: 0.0004995  max_mem: 2756M
# [11/09 14:38:03 d2.utils.events]:  eta: 0:11:24  iter: 519  total_loss: 0.7868  loss_cls: 0.1389  loss_box_reg: 0.4122  loss_mask: 0.1849  loss_rpn_cls: 0.008821  loss_rpn_loc: 0.05754  time: 0.4639  data_time: 0.0128  lr: 0.00051948  max_mem: 2756M
# [11/09 14:38:12 d2.utils.events]:  eta: 0:11:15  iter: 539  total_loss: 0.7888  loss_cls: 0.1378  loss_box_reg: 0.3638  loss_mask: 0.1636  loss_rpn_cls: 0.004859  loss_rpn_loc: 0.06672  time: 0.4637  data_time: 0.0092  lr: 0.00053946  max_mem: 2756M
# [11/09 14:38:22 d2.utils.events]:  eta: 0:11:07  iter: 559  total_loss: 0.7827  loss_cls: 0.1326  loss_box_reg: 0.3688  loss_mask: 0.1843  loss_rpn_cls: 0.007706  loss_rpn_loc: 0.08861  time: 0.4640  data_time: 0.0106  lr: 0.00055944  max_mem: 2756M
# [11/09 14:38:31 d2.utils.events]:  eta: 0:10:59  iter: 579  total_loss: 0.7754  loss_cls: 0.1311  loss_box_reg: 0.4035  loss_mask: 0.1878  loss_rpn_cls: 0.008189  loss_rpn_loc: 0.06861  time: 0.4643  data_time: 0.0122  lr: 0.00057942  max_mem: 2756M
# WARNING [11/09 14:38:41 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:38:41 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:38:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:38:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:38:41 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:38:41 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:38:41 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:38:41 d2.utils.events]:  eta: 0:10:50  iter: 599  total_loss: 0.7863  loss_cls: 0.144  loss_box_reg: 0.3597  loss_mask: 0.1702  loss_rpn_cls: 0.008377  loss_rpn_loc: 0.06653  time: 0.4643  data_time: 0.0109  lr: 0.0005994  max_mem: 2756M
# [11/09 14:38:50 d2.utils.events]:  eta: 0:10:42  iter: 619  total_loss: 0.8632  loss_cls: 0.1754  loss_box_reg: 0.3904  loss_mask: 0.1899  loss_rpn_cls: 0.01564  loss_rpn_loc: 0.0778  time: 0.4646  data_time: 0.0110  lr: 0.00061938  max_mem: 2756M
# [11/09 14:38:59 d2.utils.events]:  eta: 0:10:32  iter: 639  total_loss: 0.7888  loss_cls: 0.1298  loss_box_reg: 0.4072  loss_mask: 0.1581  loss_rpn_cls: 0.004993  loss_rpn_loc: 0.07809  time: 0.4648  data_time: 0.0127  lr: 0.00063936  max_mem: 2756M
# [11/09 14:39:09 d2.utils.events]:  eta: 0:10:23  iter: 659  total_loss: 0.7536  loss_cls: 0.1266  loss_box_reg: 0.3532  loss_mask: 0.1867  loss_rpn_cls: 0.01227  loss_rpn_loc: 0.07327  time: 0.4649  data_time: 0.0141  lr: 0.00065934  max_mem: 2756M
# [11/09 14:39:18 d2.utils.events]:  eta: 0:10:14  iter: 679  total_loss: 0.7347  loss_cls: 0.1276  loss_box_reg: 0.3576  loss_mask: 0.1602  loss_rpn_cls: 0.009823  loss_rpn_loc: 0.06826  time: 0.4650  data_time: 0.0126  lr: 0.00067932  max_mem: 2756M
# [11/09 14:39:28 d2.utils.events]:  eta: 0:10:05  iter: 699  total_loss: 0.7019  loss_cls: 0.1329  loss_box_reg: 0.3271  loss_mask: 0.1427  loss_rpn_cls: 0.007694  loss_rpn_loc: 0.07753  time: 0.4654  data_time: 0.0115  lr: 0.0006993  max_mem: 2756M
# [11/09 14:39:37 d2.utils.events]:  eta: 0:09:56  iter: 719  total_loss: 0.6646  loss_cls: 0.1033  loss_box_reg: 0.3019  loss_mask: 0.1448  loss_rpn_cls: 0.006378  loss_rpn_loc: 0.07085  time: 0.4652  data_time: 0.0093  lr: 0.00071928  max_mem: 2756M
# [11/09 14:39:47 d2.utils.events]:  eta: 0:09:48  iter: 739  total_loss: 0.6566  loss_cls: 0.1234  loss_box_reg: 0.3193  loss_mask: 0.1274  loss_rpn_cls: 0.008046  loss_rpn_loc: 0.06926  time: 0.4659  data_time: 0.0126  lr: 0.00073926  max_mem: 2756M
# [11/09 14:39:56 d2.utils.events]:  eta: 0:09:38  iter: 759  total_loss: 0.6304  loss_cls: 0.09196  loss_box_reg: 0.2869  loss_mask: 0.1398  loss_rpn_cls: 0.008657  loss_rpn_loc: 0.05738  time: 0.4658  data_time: 0.0141  lr: 0.00075924  max_mem: 2756M
# [11/09 14:40:05 d2.utils.events]:  eta: 0:09:29  iter: 779  total_loss: 0.6372  loss_cls: 0.111  loss_box_reg: 0.309  loss_mask: 0.1574  loss_rpn_cls: 0.006766  loss_rpn_loc: 0.06111  time: 0.4659  data_time: 0.0122  lr: 0.00077922  max_mem: 2756M
# WARNING [11/09 14:40:15 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:40:15 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:40:15 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:40:15 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:40:15 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:40:15 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:40:15 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:40:15 d2.utils.events]:  eta: 0:09:20  iter: 799  total_loss: 0.7586  loss_cls: 0.1275  loss_box_reg: 0.3675  loss_mask: 0.1677  loss_rpn_cls: 0.007176  loss_rpn_loc: 0.06995  time: 0.4662  data_time: 0.0120  lr: 0.0007992  max_mem: 2756M
# [11/09 14:40:25 d2.utils.events]:  eta: 0:09:11  iter: 819  total_loss: 0.7455  loss_cls: 0.1209  loss_box_reg: 0.3429  loss_mask: 0.1727  loss_rpn_cls: 0.007901  loss_rpn_loc: 0.0674  time: 0.4665  data_time: 0.0129  lr: 0.00081918  max_mem: 2756M
# [11/09 14:40:34 d2.utils.events]:  eta: 0:09:01  iter: 839  total_loss: 0.7629  loss_cls: 0.1014  loss_box_reg: 0.3294  loss_mask: 0.1657  loss_rpn_cls: 0.006144  loss_rpn_loc: 0.06737  time: 0.4665  data_time: 0.0093  lr: 0.00083916  max_mem: 2756M
# [11/09 14:40:43 d2.utils.events]:  eta: 0:08:52  iter: 859  total_loss: 0.6459  loss_cls: 0.1041  loss_box_reg: 0.3205  loss_mask: 0.1327  loss_rpn_cls: 0.005221  loss_rpn_loc: 0.06804  time: 0.4665  data_time: 0.0118  lr: 0.00085914  max_mem: 2756M
# [11/09 14:40:53 d2.utils.events]:  eta: 0:08:42  iter: 879  total_loss: 0.7423  loss_cls: 0.1306  loss_box_reg: 0.3352  loss_mask: 0.1494  loss_rpn_cls: 0.00678  loss_rpn_loc: 0.05873  time: 0.4665  data_time: 0.0108  lr: 0.00087912  max_mem: 2756M
# [11/09 14:41:02 d2.utils.events]:  eta: 0:08:33  iter: 899  total_loss: 0.5988  loss_cls: 0.09529  loss_box_reg: 0.2904  loss_mask: 0.1437  loss_rpn_cls: 0.003785  loss_rpn_loc: 0.05169  time: 0.4662  data_time: 0.0108  lr: 0.0008991  max_mem: 2756M
# [11/09 14:41:11 d2.utils.events]:  eta: 0:08:24  iter: 919  total_loss: 0.6762  loss_cls: 0.09349  loss_box_reg: 0.3295  loss_mask: 0.1459  loss_rpn_cls: 0.01005  loss_rpn_loc: 0.05216  time: 0.4665  data_time: 0.0136  lr: 0.00091908  max_mem: 2756M
# [11/09 14:41:21 d2.utils.events]:  eta: 0:08:14  iter: 939  total_loss: 0.6881  loss_cls: 0.1017  loss_box_reg: 0.3302  loss_mask: 0.1292  loss_rpn_cls: 0.01175  loss_rpn_loc: 0.07802  time: 0.4665  data_time: 0.0148  lr: 0.00093906  max_mem: 2756M
# [11/09 14:41:30 d2.utils.events]:  eta: 0:08:05  iter: 959  total_loss: 0.6059  loss_cls: 0.09874  loss_box_reg: 0.3059  loss_mask: 0.1322  loss_rpn_cls: 0.009944  loss_rpn_loc: 0.05194  time: 0.4663  data_time: 0.0139  lr: 0.00095904  max_mem: 2756M
# [11/09 14:41:39 d2.utils.events]:  eta: 0:07:56  iter: 979  total_loss: 0.5461  loss_cls: 0.08167  loss_box_reg: 0.2568  loss_mask: 0.1133  loss_rpn_cls: 0.002922  loss_rpn_loc: 0.05348  time: 0.4665  data_time: 0.0126  lr: 0.00097902  max_mem: 2756M
# WARNING [11/09 14:41:49 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:41:49 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:41:49 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:41:49 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:41:49 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:41:49 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:41:49 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:41:49 d2.utils.events]:  eta: 0:07:46  iter: 999  total_loss: 0.7139  loss_cls: 0.1002  loss_box_reg: 0.3366  loss_mask: 0.143  loss_rpn_cls: 0.005221  loss_rpn_loc: 0.04767  time: 0.4668  data_time: 0.0109  lr: 0.000999  max_mem: 2756M
# [11/09 14:41:58 d2.utils.events]:  eta: 0:07:37  iter: 1019  total_loss: 0.6385  loss_cls: 0.09321  loss_box_reg: 0.309  loss_mask: 0.146  loss_rpn_cls: 0.008982  loss_rpn_loc: 0.06591  time: 0.4665  data_time: 0.0140  lr: 0.001  max_mem: 2756M
# [11/09 14:42:07 d2.utils.events]:  eta: 0:07:28  iter: 1039  total_loss: 0.5956  loss_cls: 0.1025  loss_box_reg: 0.2768  loss_mask: 0.1412  loss_rpn_cls: 0.00454  loss_rpn_loc: 0.06104  time: 0.4664  data_time: 0.0123  lr: 0.001  max_mem: 2756M
# [11/09 14:42:17 d2.utils.events]:  eta: 0:07:19  iter: 1059  total_loss: 0.6362  loss_cls: 0.08778  loss_box_reg: 0.2838  loss_mask: 0.1247  loss_rpn_cls: 0.004675  loss_rpn_loc: 0.06264  time: 0.4666  data_time: 0.0100  lr: 0.001  max_mem: 2756M
# [11/09 14:42:27 d2.utils.events]:  eta: 0:07:10  iter: 1079  total_loss: 0.6187  loss_cls: 0.101  loss_box_reg: 0.2661  loss_mask: 0.1262  loss_rpn_cls: 0.006873  loss_rpn_loc: 0.05833  time: 0.4669  data_time: 0.0098  lr: 0.001  max_mem: 2756M
# [11/09 14:42:36 d2.utils.events]:  eta: 0:07:01  iter: 1099  total_loss: 0.542  loss_cls: 0.0862  loss_box_reg: 0.2721  loss_mask: 0.1237  loss_rpn_cls: 0.00555  loss_rpn_loc: 0.04905  time: 0.4669  data_time: 0.0124  lr: 0.001  max_mem: 2756M
# [11/09 14:42:46 d2.utils.events]:  eta: 0:06:52  iter: 1119  total_loss: 0.5887  loss_cls: 0.09241  loss_box_reg: 0.2857  loss_mask: 0.132  loss_rpn_cls: 0.005374  loss_rpn_loc: 0.06341  time: 0.4672  data_time: 0.0113  lr: 0.001  max_mem: 2756M
# [11/09 14:42:55 d2.utils.events]:  eta: 0:06:43  iter: 1139  total_loss: 0.5062  loss_cls: 0.07308  loss_box_reg: 0.2496  loss_mask: 0.1148  loss_rpn_cls: 0.005251  loss_rpn_loc: 0.04904  time: 0.4671  data_time: 0.0094  lr: 0.001  max_mem: 2756M
# [11/09 14:43:04 d2.utils.events]:  eta: 0:06:33  iter: 1159  total_loss: 0.5206  loss_cls: 0.08528  loss_box_reg: 0.2898  loss_mask: 0.1089  loss_rpn_cls: 0.005057  loss_rpn_loc: 0.05055  time: 0.4670  data_time: 0.0104  lr: 0.001  max_mem: 2756M
# [11/09 14:43:14 d2.utils.events]:  eta: 0:06:24  iter: 1179  total_loss: 0.5286  loss_cls: 0.07321  loss_box_reg: 0.2637  loss_mask: 0.1114  loss_rpn_cls: 0.005966  loss_rpn_loc: 0.05571  time: 0.4673  data_time: 0.0104  lr: 0.001  max_mem: 2756M
# WARNING [11/09 14:43:23 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:43:23 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:43:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:43:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:43:23 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:43:23 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:43:23 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:43:23 d2.utils.events]:  eta: 0:06:15  iter: 1199  total_loss: 0.5257  loss_cls: 0.07823  loss_box_reg: 0.2744  loss_mask: 0.1174  loss_rpn_cls: 0.005785  loss_rpn_loc: 0.04173  time: 0.4673  data_time: 0.0129  lr: 0.001  max_mem: 2756M
# [11/09 14:43:32 d2.utils.events]:  eta: 0:06:05  iter: 1219  total_loss: 0.5556  loss_cls: 0.08147  loss_box_reg: 0.2664  loss_mask: 0.1263  loss_rpn_cls: 0.005201  loss_rpn_loc: 0.05511  time: 0.4672  data_time: 0.0119  lr: 0.001  max_mem: 2756M
# [11/09 14:43:42 d2.utils.events]:  eta: 0:05:56  iter: 1239  total_loss: 0.4654  loss_cls: 0.06534  loss_box_reg: 0.2355  loss_mask: 0.1149  loss_rpn_cls: 0.006031  loss_rpn_loc: 0.04471  time: 0.4672  data_time: 0.0113  lr: 0.001  max_mem: 2756M
# [11/09 14:43:51 d2.utils.events]:  eta: 0:05:46  iter: 1259  total_loss: 0.482  loss_cls: 0.07497  loss_box_reg: 0.2355  loss_mask: 0.1005  loss_rpn_cls: 0.004128  loss_rpn_loc: 0.0574  time: 0.4672  data_time: 0.0104  lr: 0.001  max_mem: 2756M
# [11/09 14:44:01 d2.utils.events]:  eta: 0:05:37  iter: 1279  total_loss: 0.4699  loss_cls: 0.08038  loss_box_reg: 0.2253  loss_mask: 0.1084  loss_rpn_cls: 0.003207  loss_rpn_loc: 0.04958  time: 0.4673  data_time: 0.0101  lr: 0.001  max_mem: 2756M
# [11/09 14:44:10 d2.utils.events]:  eta: 0:05:28  iter: 1299  total_loss: 0.495  loss_cls: 0.06213  loss_box_reg: 0.2339  loss_mask: 0.1099  loss_rpn_cls: 0.003691  loss_rpn_loc: 0.04493  time: 0.4671  data_time: 0.0129  lr: 0.001  max_mem: 2756M
# [11/09 14:44:19 d2.utils.events]:  eta: 0:05:18  iter: 1319  total_loss: 0.4775  loss_cls: 0.06302  loss_box_reg: 0.2461  loss_mask: 0.09658  loss_rpn_cls: 0.00397  loss_rpn_loc: 0.04937  time: 0.4669  data_time: 0.0100  lr: 0.001  max_mem: 2756M
# [11/09 14:44:29 d2.utils.events]:  eta: 0:05:09  iter: 1339  total_loss: 0.4641  loss_cls: 0.06857  loss_box_reg: 0.2376  loss_mask: 0.1034  loss_rpn_cls: 0.003134  loss_rpn_loc: 0.05704  time: 0.4672  data_time: 0.0106  lr: 0.001  max_mem: 2756M
# [11/09 14:44:38 d2.utils.events]:  eta: 0:05:00  iter: 1359  total_loss: 0.6308  loss_cls: 0.0821  loss_box_reg: 0.2846  loss_mask: 0.1311  loss_rpn_cls: 0.003434  loss_rpn_loc: 0.04831  time: 0.4674  data_time: 0.0112  lr: 0.001  max_mem: 2756M
# [11/09 14:44:48 d2.utils.events]:  eta: 0:04:51  iter: 1379  total_loss: 0.5173  loss_cls: 0.07072  loss_box_reg: 0.265  loss_mask: 0.1163  loss_rpn_cls: 0.003176  loss_rpn_loc: 0.04744  time: 0.4674  data_time: 0.0093  lr: 0.001  max_mem: 2756M
# WARNING [11/09 14:44:57 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:44:57 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:44:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:44:57 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:44:57 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:44:57 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:44:57 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:44:57 d2.utils.events]:  eta: 0:04:41  iter: 1399  total_loss: 0.4807  loss_cls: 0.06553  loss_box_reg: 0.2265  loss_mask: 0.1073  loss_rpn_cls: 0.003559  loss_rpn_loc: 0.0551  time: 0.4673  data_time: 0.0132  lr: 0.001  max_mem: 2756M
# [11/09 14:45:06 d2.utils.events]:  eta: 0:04:32  iter: 1419  total_loss: 0.463  loss_cls: 0.06257  loss_box_reg: 0.2249  loss_mask: 0.0959  loss_rpn_cls: 0.00384  loss_rpn_loc: 0.05318  time: 0.4672  data_time: 0.0120  lr: 0.001  max_mem: 2756M
# [11/09 14:45:15 d2.utils.events]:  eta: 0:04:22  iter: 1439  total_loss: 0.409  loss_cls: 0.05221  loss_box_reg: 0.2077  loss_mask: 0.09596  loss_rpn_cls: 0.002472  loss_rpn_loc: 0.03548  time: 0.4671  data_time: 0.0093  lr: 0.001  max_mem: 2756M
# [11/09 14:45:25 d2.utils.events]:  eta: 0:04:13  iter: 1459  total_loss: 0.4704  loss_cls: 0.06346  loss_box_reg: 0.2268  loss_mask: 0.09904  loss_rpn_cls: 0.00497  loss_rpn_loc: 0.04813  time: 0.4672  data_time: 0.0109  lr: 0.001  max_mem: 2756M
# [11/09 14:45:34 d2.utils.events]:  eta: 0:04:04  iter: 1479  total_loss: 0.4928  loss_cls: 0.0572  loss_box_reg: 0.2449  loss_mask: 0.1028  loss_rpn_cls: 0.00442  loss_rpn_loc: 0.05566  time: 0.4673  data_time: 0.0143  lr: 0.001  max_mem: 2756M
# [11/09 14:45:44 d2.utils.events]:  eta: 0:03:54  iter: 1499  total_loss: 0.3875  loss_cls: 0.04607  loss_box_reg: 0.2007  loss_mask: 0.09933  loss_rpn_cls: 0.005119  loss_rpn_loc: 0.03647  time: 0.4676  data_time: 0.0114  lr: 0.001  max_mem: 2756M
# [11/09 14:45:53 d2.utils.events]:  eta: 0:03:45  iter: 1519  total_loss: 0.4464  loss_cls: 0.05477  loss_box_reg: 0.2233  loss_mask: 0.09897  loss_rpn_cls: 0.0029  loss_rpn_loc: 0.04311  time: 0.4676  data_time: 0.0108  lr: 0.001  max_mem: 2756M
# [11/09 14:46:03 d2.utils.events]:  eta: 0:03:36  iter: 1539  total_loss: 0.4465  loss_cls: 0.07582  loss_box_reg: 0.1986  loss_mask: 0.1  loss_rpn_cls: 0.004319  loss_rpn_loc: 0.04256  time: 0.4677  data_time: 0.0102  lr: 0.001  max_mem: 2756M
# [11/09 14:46:12 d2.utils.events]:  eta: 0:03:26  iter: 1559  total_loss: 0.4618  loss_cls: 0.06131  loss_box_reg: 0.2413  loss_mask: 0.0993  loss_rpn_cls: 0.003543  loss_rpn_loc: 0.06012  time: 0.4677  data_time: 0.0133  lr: 0.001  max_mem: 2756M
# [11/09 14:46:22 d2.utils.events]:  eta: 0:03:17  iter: 1579  total_loss: 0.3918  loss_cls: 0.05408  loss_box_reg: 0.2049  loss_mask: 0.09499  loss_rpn_cls: 0.002409  loss_rpn_loc: 0.04814  time: 0.4678  data_time: 0.0117  lr: 0.001  max_mem: 2756M
# WARNING [11/09 14:46:31 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:46:31 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:46:31 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:46:31 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:46:31 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:46:31 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:46:31 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:46:31 d2.utils.events]:  eta: 0:03:07  iter: 1599  total_loss: 0.4507  loss_cls: 0.05292  loss_box_reg: 0.216  loss_mask: 0.09717  loss_rpn_cls: 0.0034  loss_rpn_loc: 0.0519  time: 0.4678  data_time: 0.0127  lr: 0.001  max_mem: 2756M
# [11/09 14:46:41 d2.utils.events]:  eta: 0:02:58  iter: 1619  total_loss: 0.4014  loss_cls: 0.06307  loss_box_reg: 0.183  loss_mask: 0.08177  loss_rpn_cls: 0.002204  loss_rpn_loc: 0.04968  time: 0.4680  data_time: 0.0121  lr: 0.001  max_mem: 2756M
# [11/09 14:46:50 d2.utils.events]:  eta: 0:02:49  iter: 1639  total_loss: 0.4337  loss_cls: 0.06151  loss_box_reg: 0.216  loss_mask: 0.09549  loss_rpn_cls: 0.003407  loss_rpn_loc: 0.04709  time: 0.4679  data_time: 0.0097  lr: 0.001  max_mem: 2756M
# [11/09 14:47:00 d2.utils.events]:  eta: 0:02:39  iter: 1659  total_loss: 0.4384  loss_cls: 0.06392  loss_box_reg: 0.2127  loss_mask: 0.1005  loss_rpn_cls: 0.002804  loss_rpn_loc: 0.04236  time: 0.4679  data_time: 0.0106  lr: 0.001  max_mem: 2756M
# [11/09 14:47:09 d2.utils.events]:  eta: 0:02:30  iter: 1679  total_loss: 0.3661  loss_cls: 0.05758  loss_box_reg: 0.1872  loss_mask: 0.09213  loss_rpn_cls: 0.002701  loss_rpn_loc: 0.04281  time: 0.4683  data_time: 0.0089  lr: 0.001  max_mem: 2756M
# [11/09 14:47:19 d2.utils.events]:  eta: 0:02:21  iter: 1699  total_loss: 0.4029  loss_cls: 0.05432  loss_box_reg: 0.223  loss_mask: 0.08425  loss_rpn_cls: 0.002858  loss_rpn_loc: 0.04957  time: 0.4685  data_time: 0.0115  lr: 0.001  max_mem: 2756M
# [11/09 14:47:29 d2.utils.events]:  eta: 0:02:11  iter: 1719  total_loss: 0.4016  loss_cls: 0.05655  loss_box_reg: 0.2139  loss_mask: 0.08689  loss_rpn_cls: 0.004493  loss_rpn_loc: 0.04199  time: 0.4684  data_time: 0.0101  lr: 0.001  max_mem: 2756M
# [11/09 14:47:38 d2.utils.events]:  eta: 0:02:02  iter: 1739  total_loss: 0.4811  loss_cls: 0.07221  loss_box_reg: 0.2503  loss_mask: 0.1099  loss_rpn_cls: 0.003325  loss_rpn_loc: 0.03339  time: 0.4683  data_time: 0.0113  lr: 0.001  max_mem: 2756M
# [11/09 14:47:47 d2.utils.events]:  eta: 0:01:52  iter: 1759  total_loss: 0.4486  loss_cls: 0.05913  loss_box_reg: 0.226  loss_mask: 0.08758  loss_rpn_cls: 0.002717  loss_rpn_loc: 0.04174  time: 0.4685  data_time: 0.0120  lr: 0.001  max_mem: 2756M
# [11/09 14:47:57 d2.utils.events]:  eta: 0:01:43  iter: 1779  total_loss: 0.3816  loss_cls: 0.06197  loss_box_reg: 0.1888  loss_mask: 0.08656  loss_rpn_cls: 0.004682  loss_rpn_loc: 0.03959  time: 0.4685  data_time: 0.0102  lr: 0.001  max_mem: 2756M
# WARNING [11/09 14:48:07 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:48:07 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:48:07 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:48:07 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:48:07 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:48:07 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:48:07 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [11/09 14:48:07 d2.utils.events]:  eta: 0:01:34  iter: 1799  total_loss: 0.4387  loss_cls: 0.07173  loss_box_reg: 0.2214  loss_mask: 0.09586  loss_rpn_cls: 0.002667  loss_rpn_loc: 0.05712  time: 0.4687  data_time: 0.0097  lr: 0.001  max_mem: 2756M
# [11/09 14:48:16 d2.utils.events]:  eta: 0:01:24  iter: 1819  total_loss: 0.4534  loss_cls: 0.05993  loss_box_reg: 0.2147  loss_mask: 0.101  loss_rpn_cls: 0.004536  loss_rpn_loc: 0.05518  time: 0.4688  data_time: 0.0114  lr: 0.001  max_mem: 2756M
# [11/09 14:48:26 d2.utils.events]:  eta: 0:01:15  iter: 1839  total_loss: 0.367  loss_cls: 0.05343  loss_box_reg: 0.1812  loss_mask: 0.09196  loss_rpn_cls: 0.002379  loss_rpn_loc: 0.03615  time: 0.4688  data_time: 0.0099  lr: 0.001  max_mem: 2756M
# [11/09 14:48:35 d2.utils.events]:  eta: 0:01:05  iter: 1859  total_loss: 0.3983  loss_cls: 0.06674  loss_box_reg: 0.2013  loss_mask: 0.08759  loss_rpn_cls: 0.005513  loss_rpn_loc: 0.0445  time: 0.4687  data_time: 0.0130  lr: 0.001  max_mem: 2756M
# [11/09 14:48:44 d2.utils.events]:  eta: 0:00:56  iter: 1879  total_loss: 0.3799  loss_cls: 0.05273  loss_box_reg: 0.1895  loss_mask: 0.09282  loss_rpn_cls: 0.002347  loss_rpn_loc: 0.033  time: 0.4686  data_time: 0.0107  lr: 0.001  max_mem: 2756M
# [11/09 14:48:53 d2.utils.events]:  eta: 0:00:47  iter: 1899  total_loss: 0.3886  loss_cls: 0.04457  loss_box_reg: 0.2102  loss_mask: 0.08301  loss_rpn_cls: 0.002129  loss_rpn_loc: 0.04297  time: 0.4686  data_time: 0.0132  lr: 0.001  max_mem: 2756M
# [11/09 14:49:03 d2.utils.events]:  eta: 0:00:37  iter: 1919  total_loss: 0.4092  loss_cls: 0.05937  loss_box_reg: 0.2036  loss_mask: 0.09364  loss_rpn_cls: 0.003279  loss_rpn_loc: 0.04874  time: 0.4686  data_time: 0.0092  lr: 0.001  max_mem: 2756M
# [11/09 14:49:12 d2.utils.events]:  eta: 0:00:28  iter: 1939  total_loss: 0.3954  loss_cls: 0.04889  loss_box_reg: 0.1952  loss_mask: 0.08204  loss_rpn_cls: 0.002722  loss_rpn_loc: 0.04362  time: 0.4684  data_time: 0.0119  lr: 0.001  max_mem: 2756M
# [11/09 14:49:21 d2.utils.events]:  eta: 0:00:18  iter: 1959  total_loss: 0.4407  loss_cls: 0.07544  loss_box_reg: 0.2039  loss_mask: 0.09686  loss_rpn_cls: 0.003889  loss_rpn_loc: 0.03982  time: 0.4685  data_time: 0.0124  lr: 0.001  max_mem: 2756M
# [11/09 14:49:31 d2.utils.events]:  eta: 0:00:09  iter: 1979  total_loss: 0.4146  loss_cls: 0.05204  loss_box_reg: 0.2158  loss_mask: 0.1015  loss_rpn_cls: 0.005977  loss_rpn_loc: 0.0489  time: 0.4685  data_time: 0.0116  lr: 0.001  max_mem: 2756M
# [11/09 14:49:42 d2.utils.events]:  eta: 0:00:00  iter: 1999  total_loss: 0.4948  loss_cls: 0.06398  loss_box_reg: 0.2237  loss_mask: 0.09528  loss_rpn_cls: 0.003891  loss_rpn_loc: 0.04743  time: 0.4687  data_time: 0.0120  lr: 0.001  max_mem: 2756M
# [11/09 14:49:42 d2.engine.hooks]: Overall training speed: 1998 iterations in 0:15:36 (0.4687 s / it)
# [11/09 14:49:42 d2.engine.hooks]: Total training time: 0:15:39 (0:00:03 on hooks)
# WARNING [11/09 14:49:42 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/09 14:49:42 d2.data.datasets.coco]: Loaded 15 images in COCO format from /content/football-pitch-segmentation-1/test/_annotations.coco.json
# [11/09 14:49:42 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/09 14:49:42 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common.NumpySerializedList'>
# [11/09 14:49:42 d2.data.common]: Serializing 15 elements to byte tensors and concatenating them all ...
# [11/09 14:49:42 d2.data.common]: Serialized dataset takes 0.01 MiB
# WARNING [11/09 14:49:42 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
# Look at training curves in tensorboard:
# %load_ext tensorboard
# %tensorboard --logdir $OUTPUT_DIR_PATH

# %% [markdown]
# ### Evaluation

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7
predictor = DefaultPredictor(cfg)

# %%
dataset_valid = DatasetCatalog.get(VALID_DATA_SET_NAME)

for d in dataset_valid:
    img = cv2.imread(d["file_name"])
    outputs = predictor(img)

    visualizer = Visualizer(
        img[:, :, ::-1],
        metadata=metadata,
        scale=0.8,
        instance_mode=ColorMode.IMAGE_BW
    )
    out = visualizer.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(out.get_image()[:, :, ::-1])
